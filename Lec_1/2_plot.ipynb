# %%
import numpy as np
import matplotlib.pyplot as plt
years=[2000 + x for x in range(10)]
weight=[57,60,43,68,34,56,67,89,94,87]
plt.plot(years,weight,c="r",lw=5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
