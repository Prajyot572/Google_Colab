# %%
import numpy as np
import matplotlib.pyplot as plt
courses = ["C#", "C", "Python", "Java", "ASP.NET"]
enrolled = [34, 37, 78, 56, 20]
plt.bar(courses, enrolled, color="r", width=0.5, edgecolor="orange")
plt.show()
